# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size=2000)
lngs = np.random.uniform(-180,180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 770

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# Print url
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=208373fb6fe08d264cbbc9e9b8bbcebf

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_maxtemp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]   
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Long": city_lng,
                          "Max Temp": city_maxtemp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | mikuni
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | praya
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | samarai
# Processing Record 15 of Set 1 | vila velha
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | cidreira
# Processing Record 19 of Set 1 | fuerte olimpo
# Processing Record 20 of Set 1 | russell
# Processing Record 21 of Set 1 | los alamos
# Processing Record 22 of Set 1 | bukachacha
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | algiers
# Processing Record 25 of Set 1 | mackay
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | nara
# Processing Record 28 of Set 1 | burica
# City not found. Skipping...
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | cortez
# Processing Record 31 of Set 1 | cabo san lucas
# Processing Record 32 of Set 1 | camapua
# Processing Record 33 of Set 1 | bud
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | vanavara
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | saint-pierre
# Processing Record 39 of Set 1 | dali
# Processing Record 40 of Set 1 | souillac
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | sao filipe
# Processing Record 43 of Set 1 | tecoanapa
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | mbandaka
# Processing Record 46 of Set 1 | dryden
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | te anau
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | trelew
# Processing Record 1 of Set 2 | koumac
# Processing Record 2 of Set 2 | makakilo city
# Processing Record 3 of Set 2 | ankazoabo
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | bubaque
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | terrace
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | lahij
# Processing Record 12 of Set 2 | dunedin
# Processing Record 13 of Set 2 | ponta do sol
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | yoichi
# Processing Record 17 of Set 2 | fort nelson
# Processing Record 18 of Set 2 | norman wells
# Processing Record 19 of Set 2 | solano
# Processing Record 20 of Set 2 | constitucion
# Processing Record 21 of Set 2 | firovo
# Processing Record 22 of Set 2 | tuatapere
# Processing Record 23 of Set 2 | lavrentiya
# Processing Record 24 of Set 2 | mataura
# Processing Record 25 of Set 2 | port hardy
# Processing Record 26 of Set 2 | mandalgovi
# Processing Record 27 of Set 2 | ciudad guayana
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | seoul
# Processing Record 30 of Set 2 | sao joao da barra
# Processing Record 31 of Set 2 | ternitz
# Processing Record 32 of Set 2 | nagua
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | songea
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | andenes
# Processing Record 37 of Set 2 | neepawa
# Processing Record 38 of Set 2 | jaisalmer
# Processing Record 39 of Set 2 | port lincoln
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | usinsk
# Processing Record 42 of Set 2 | wajir
# Processing Record 43 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 2 | busselton
# Processing Record 46 of Set 2 | saint anthony
# Processing Record 47 of Set 2 | college
# Processing Record 48 of Set 2 | ancud
# Processing Record 49 of Set 2 | pangody
# Processing Record 50 of Set 2 | port alfred
# Processing Record 1 of Set 3 | balaipungut
# Processing Record 2 of Set 3 | camabatela
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | marawi
# Processing Record 5 of Set 3 | teya
# Processing Record 6 of Set 3 | kristiansund
# Processing Record 7 of Set 3 | jumla
# Processing Record 8 of Set 3 | margate
# Processing Record 9 of Set 3 | dicabisagan
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | clifton
# Processing Record 12 of Set 3 | mount gambier
# Processing Record 13 of Set 3 | gilbues
# Processing Record 14 of Set 3 | maryville
# Processing Record 15 of Set 3 | xam nua
# Processing Record 16 of Set 3 | cerrito
# Processing Record 17 of Set 3 | bilma
# Processing Record 18 of Set 3 | zaysan
# Processing Record 19 of Set 3 | sanok
# Processing Record 20 of Set 3 | dikson
# Processing Record 21 of Set 3 | sodertalje
# City not found. Skipping...
# Processing Record 22 of Set 3 | dongsheng
# Processing Record 23 of Set 3 | nikolskoye
# Processing Record 24 of Set 3 | peniche
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | jahrom
# City not found. Skipping...
# Processing Record 27 of Set 3 | chaihe
# Processing Record 28 of Set 3 | klaksvik
# Processing Record 29 of Set 3 | vila do maio
# Processing Record 30 of Set 3 | kirando
# Processing Record 31 of Set 3 | kholodnyy
# Processing Record 32 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 3 | sabha
# Processing Record 34 of Set 3 | luklukan
# Processing Record 35 of Set 3 | pacific grove
# Processing Record 36 of Set 3 | marsh harbour
# Processing Record 37 of Set 3 | nacogdoches
# Processing Record 38 of Set 3 | narsaq
# Processing Record 39 of Set 3 | saldanha
# Processing Record 40 of Set 3 | vaitape
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | okato
# Processing Record 43 of Set 3 | albany
# Processing Record 44 of Set 3 | necochea
# Processing Record 45 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 3 | wanaka
# Processing Record 47 of Set 3 | alta floresta
# Processing Record 48 of Set 3 | nome
# Processing Record 49 of Set 3 | vardo
# Processing Record 50 of Set 3 | berlevag
# Processing Record 1 of Set 4 | san jose
# Processing Record 2 of Set 4 | candelaria
# Processing Record 3 of Set 4 | visby
# Processing Record 4 of Set 4 | iqaluit
# Processing Record 5 of Set 4 | hildesheim
# Processing Record 6 of Set 4 | vao
# Processing Record 7 of Set 4 | dobsina
# Processing Record 8 of Set 4 | surt
# Processing Record 9 of Set 4 | chapais
# Processing Record 10 of Set 4 | miles city
# Processing Record 11 of Set 4 | ribeira grande
# Processing Record 12 of Set 4 | tucurui
# Processing Record 13 of Set 4 | santiago
# Processing Record 14 of Set 4 | leningradskiy
# Processing Record 15 of Set 4 | deputatskiy
# Processing Record 16 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 4 | tiksi
# Processing Record 18 of Set 4 | muscat
# Processing Record 19 of Set 4 | klyuchi
# Processing Record 20 of Set 4 | barrow
# Processing Record 21 of Set 4 | castro
# Processing Record 22 of Set 4 | la brea
# Processing Record 23 of Set 4 | kashan
# Processing Record 24 of Set 4 | tibati
# Processing Record 25 of Set 4 | mao
# Processing Record 26 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 4 | biak
# Processing Record 28 of Set 4 | luderitz
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 4 | port macquarie
# Processing Record 32 of Set 4 | saint george
# Processing Record 33 of Set 4 | plettenberg bay
# Processing Record 34 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 4 | pangnirtung
# Processing Record 36 of Set 4 | berbera
# Processing Record 37 of Set 4 | kieta
# Processing Record 38 of Set 4 | troitsko-pechorsk
# Processing Record 39 of Set 4 | tuni
# Processing Record 40 of Set 4 | viesca
# Processing Record 41 of Set 4 | moose factory
# Processing Record 42 of Set 4 | egvekinot
# Processing Record 43 of Set 4 | ilulissat
# Processing Record 44 of Set 4 | kenai
# Processing Record 45 of Set 4 | airai
# Processing Record 46 of Set 4 | sorland
# Processing Record 47 of Set 4 | lenki
# City not found. Skipping...
# Processing Record 48 of Set 4 | kaitangata
# Processing Record 49 of Set 4 | alexander city
# Processing Record 50 of Set 4 | chuy
# Processing Record 1 of Set 5 | mahebourg
# Processing Record 2 of Set 5 | belaya gora
# Processing Record 3 of Set 5 | easton
# Processing Record 4 of Set 5 | avarua
# Processing Record 5 of Set 5 | kushima
# Processing Record 6 of Set 5 | shiloh
# Processing Record 7 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 5 | richards bay
# Processing Record 9 of Set 5 | shimoda
# Processing Record 10 of Set 5 | maceio
# Processing Record 11 of Set 5 | hami
# Processing Record 12 of Set 5 | axim
# Processing Record 13 of Set 5 | meghri
# Processing Record 14 of Set 5 | sile
# Processing Record 15 of Set 5 | belmonte
# Processing Record 16 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 5 | burns lake
# Processing Record 18 of Set 5 | ruwi
# Processing Record 19 of Set 5 | aykhal
# Processing Record 20 of Set 5 | koppies
# Processing Record 21 of Set 5 | hofn
# Processing Record 22 of Set 5 | dasoguz
# Processing Record 23 of Set 5 | ca mau
# Processing Record 24 of Set 5 | sambava
# Processing Record 25 of Set 5 | yeppoon
# Processing Record 26 of Set 5 | coloncito
# Processing Record 27 of Set 5 | ahuimanu
# Processing Record 28 of Set 5 | zalantun
# Processing Record 29 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 5 | qasigiannguit
# Processing Record 31 of Set 5 | wattegama
# Processing Record 32 of Set 5 | yei
# Processing Record 33 of Set 5 | baiyin
# Processing Record 34 of Set 5 | bukene
# Processing Record 35 of Set 5 | saint-philippe
# Processing Record 36 of Set 5 | nuuk
# Processing Record 37 of Set 5 | moron
# Processing Record 38 of Set 5 | cienfuegos
# Processing Record 39 of Set 5 | severodvinsk
# Processing Record 40 of Set 5 | camacha
# Processing Record 41 of Set 5 | kerema
# Processing Record 42 of Set 5 | nanortalik
# Processing Record 43 of Set 5 | fairbanks
# Processing Record 44 of Set 5 | tilichiki
# Processing Record 45 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 46 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 47 of Set 5 | sarh
# Processing Record 48 of Set 5 | bredasdorp
# Processing Record 49 of Set 5 | poya
# Processing Record 50 of Set 5 | kayerkan
# Processing Record 1 of Set 6 | wakkanai
# Processing Record 2 of Set 6 | asau
# Processing Record 3 of Set 6 | taoudenni
# Processing Record 4 of Set 6 | chimore
# Processing Record 5 of Set 6 | cabatuan
# Processing Record 6 of Set 6 | filadelfia
# Processing Record 7 of Set 6 | ayorou
# Processing Record 8 of Set 6 | rawson
# Processing Record 9 of Set 6 | bol
# Processing Record 10 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 6 | esperance
# Processing Record 12 of Set 6 | ouesso
# Processing Record 13 of Set 6 | kununurra
# Processing Record 14 of Set 6 | comodoro rivadavia
# Processing Record 15 of Set 6 | anadyr
# Processing Record 16 of Set 6 | clyde river
# Processing Record 17 of Set 6 | waingapu
# Processing Record 18 of Set 6 | le portel
# Processing Record 19 of Set 6 | bahia blanca
# Processing Record 20 of Set 6 | road town
# Processing Record 21 of Set 6 | kuching
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | tautira
# Processing Record 24 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 26 of Set 6 | katsuura
# Processing Record 27 of Set 6 | sistranda
# Processing Record 28 of Set 6 | cockburn town
# Processing Record 29 of Set 6 | tillabery
# City not found. Skipping...
# Processing Record 30 of Set 6 | pevek
# Processing Record 31 of Set 6 | kita
# Processing Record 32 of Set 6 | san angelo
# Processing Record 33 of Set 6 | sobolevo
# Processing Record 34 of Set 6 | kilindoni
# Processing Record 35 of Set 6 | hamilton
# Processing Record 36 of Set 6 | yumen
# Processing Record 37 of Set 6 | hasaki
# Processing Record 38 of Set 6 | nelson bay
# Processing Record 39 of Set 6 | nantucket
# Processing Record 40 of Set 6 | ostrovnoy
# Processing Record 41 of Set 6 | khatanga
# Processing Record 42 of Set 6 | oktyabrskoye
# Processing Record 43 of Set 6 | basse
# Processing Record 44 of Set 6 | arraial do cabo
# Processing Record 45 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 6 | panguna
# Processing Record 47 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 6 | tagusao
# Processing Record 49 of Set 6 | cherskiy
# Processing Record 50 of Set 6 | faanui
# Processing Record 1 of Set 7 | manbij
# Processing Record 2 of Set 7 | langham
# Processing Record 3 of Set 7 | salinopolis
# Processing Record 4 of Set 7 | severo-kurilsk
# Processing Record 5 of Set 7 | kastrakion
# Processing Record 6 of Set 7 | neiafu
# Processing Record 7 of Set 7 | mayor pablo lagerenza
# Processing Record 8 of Set 7 | huarmey
# Processing Record 9 of Set 7 | srednekolymsk
# Processing Record 10 of Set 7 | kamaishi
# Processing Record 11 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 7 | natal
# Processing Record 13 of Set 7 | kahului
# Processing Record 14 of Set 7 | guerrero negro
# Processing Record 15 of Set 7 | ialibu
# Processing Record 16 of Set 7 | coahuayana
# Processing Record 17 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 7 | sananduva
# Processing Record 20 of Set 7 | juneau
# Processing Record 21 of Set 7 | vestmannaeyjar
# Processing Record 22 of Set 7 | pemangkat
# Processing Record 23 of Set 7 | oranjestad
# Processing Record 24 of Set 7 | sibu
# Processing Record 25 of Set 7 | helong
# Processing Record 26 of Set 7 | potgietersrus
# City not found. Skipping...
# Processing Record 27 of Set 7 | sarangani
# Processing Record 28 of Set 7 | bulakamba
# Processing Record 29 of Set 7 | mar del plata
# Processing Record 30 of Set 7 | sundsvall
# Processing Record 31 of Set 7 | luocheng
# Processing Record 32 of Set 7 | gat
# Processing Record 33 of Set 7 | takoradi
# Processing Record 34 of Set 7 | tome
# Processing Record 35 of Set 7 | suzu
# City not found. Skipping...
# Processing Record 36 of Set 7 | san patricio
# Processing Record 37 of Set 7 | saint-francois
# Processing Record 38 of Set 7 | vostok
# Processing Record 39 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 40 of Set 7 | atambua
# Processing Record 41 of Set 7 | marzuq
# Processing Record 42 of Set 7 | pilot butte
# Processing Record 43 of Set 7 | komatipoort
# Processing Record 44 of Set 7 | auki
# Processing Record 45 of Set 7 | seydi
# Processing Record 46 of Set 7 | quelimane
# Processing Record 47 of Set 7 | bathsheba
# Processing Record 48 of Set 7 | isparta
# Processing Record 49 of Set 7 | gorshechnoye
# Processing Record 50 of Set 7 | kashi
# Processing Record 1 of Set 8 | bijar
# Processing Record 2 of Set 8 | korgen
# Processing Record 3 of Set 8 | hervey bay
# Processing Record 4 of Set 8 | dwarka
# Processing Record 5 of Set 8 | kindu
# Processing Record 6 of Set 8 | meulaboh
# Processing Record 7 of Set 8 | caravelas
# Processing Record 8 of Set 8 | nguru
# Processing Record 9 of Set 8 | aqtobe
# Processing Record 10 of Set 8 | ayan
# Processing Record 11 of Set 8 | vicosa
# Processing Record 12 of Set 8 | lagos
# Processing Record 13 of Set 8 | maniitsoq
# Processing Record 14 of Set 8 | luwuk
# Processing Record 15 of Set 8 | bereda
# Processing Record 16 of Set 8 | khandyga
# Processing Record 17 of Set 8 | port blair
# Processing Record 18 of Set 8 | maksatikha
# Processing Record 19 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 8 | ucluelet
# Processing Record 21 of Set 8 | gerede
# Processing Record 22 of Set 8 | ferme-neuve
# Processing Record 23 of Set 8 | lorengau
# Processing Record 24 of Set 8 | bethel
# Processing Record 25 of Set 8 | alanya
# Processing Record 26 of Set 8 | katsina
# Processing Record 27 of Set 8 | la ronge
# Processing Record 28 of Set 8 | bonfim
# Processing Record 29 of Set 8 | baruun-urt
# Processing Record 30 of Set 8 | calabozo
# Processing Record 31 of Set 8 | ron phibun
# Processing Record 32 of Set 8 | am timan
# Processing Record 33 of Set 8 | beringovskiy
# Processing Record 34 of Set 8 | briancon
# Processing Record 35 of Set 8 | west wendover
# Processing Record 36 of Set 8 | los llanos de aridane
# Processing Record 37 of Set 8 | kapiri mposhi
# Processing Record 38 of Set 8 | haines junction
# Processing Record 39 of Set 8 | black river
# Processing Record 40 of Set 8 | bonoua
# Processing Record 41 of Set 8 | kerki
# City not found. Skipping...
# Processing Record 42 of Set 8 | balugaon
# Processing Record 43 of Set 8 | eenhana
# Processing Record 44 of Set 8 | bengkulu
# Processing Record 45 of Set 8 | hirtshals
# Processing Record 46 of Set 8 | norman
# Processing Record 47 of Set 8 | eyl
# Processing Record 48 of Set 8 | aksarka
# Processing Record 49 of Set 8 | rio grande
# Processing Record 50 of Set 8 | lourdes
# Processing Record 1 of Set 9 | laa
# Processing Record 2 of Set 9 | laredo
# Processing Record 3 of Set 9 | puebla
# Processing Record 4 of Set 9 | zholymbet
# Processing Record 5 of Set 9 | jibuti
# Processing Record 6 of Set 9 | tayga
# Processing Record 7 of Set 9 | bilibino
# Processing Record 8 of Set 9 | cua
# Processing Record 9 of Set 9 | christchurch
# Processing Record 10 of Set 9 | buala
# Processing Record 11 of Set 9 | dingle
# Processing Record 12 of Set 9 | komsomolskiy
# Processing Record 13 of Set 9 | jiangyou
# Processing Record 14 of Set 9 | blagoyevo
# Processing Record 15 of Set 9 | paris
# Processing Record 16 of Set 9 | nampula
# Processing Record 17 of Set 9 | san quintin
# Processing Record 18 of Set 9 | along
# Processing Record 19 of Set 9 | alappuzha
# Processing Record 20 of Set 9 | camiri
# Processing Record 21 of Set 9 | uribia
# Processing Record 22 of Set 9 | coquimbo
# Processing Record 23 of Set 9 | wembley
# Processing Record 24 of Set 9 | coihaique
# Processing Record 25 of Set 9 | tanuma
# Processing Record 26 of Set 9 | raudeberg
# Processing Record 27 of Set 9 | xinyu
# Processing Record 28 of Set 9 | bonavista
# Processing Record 29 of Set 9 | lompoc
# Processing Record 30 of Set 9 | volosovo
# Processing Record 31 of Set 9 | kavaratti
# Processing Record 32 of Set 9 | tukan
# Processing Record 33 of Set 9 | kasongo-lunda
# Processing Record 34 of Set 9 | naze
# Processing Record 35 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 36 of Set 9 | kota kinabalu
# Processing Record 37 of Set 9 | chernyshevskiy
# Processing Record 38 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 9 | umkomaas
# Processing Record 40 of Set 9 | lazaro cardenas
# Processing Record 41 of Set 9 | malindi
# Processing Record 42 of Set 9 | leninskoye
# Processing Record 43 of Set 9 | sao domingos do prata
# Processing Record 44 of Set 9 | flinders
# Processing Record 45 of Set 9 | aleksandrovka
# Processing Record 46 of Set 9 | norcasia
# Processing Record 47 of Set 9 | independence
# Processing Record 48 of Set 9 | colares
# Processing Record 49 of Set 9 | praia da vitoria
# Processing Record 50 of Set 9 | pontes e lacerda
# Processing Record 1 of Set 10 | lubliniec
# Processing Record 2 of Set 10 | zomin
# Processing Record 3 of Set 10 | oudtshoorn
# Processing Record 4 of Set 10 | yarim
# Processing Record 5 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 6 of Set 10 | landerneau
# Processing Record 7 of Set 10 | solnechnyy
# Processing Record 8 of Set 10 | belmopan
# Processing Record 9 of Set 10 | fonte boa
# Processing Record 10 of Set 10 | bukama
# Processing Record 11 of Set 10 | pauini
# Processing Record 12 of Set 10 | murgab
# Processing Record 13 of Set 10 | zabol
# Processing Record 14 of Set 10 | broken hill
# Processing Record 15 of Set 10 | hobyo
# Processing Record 16 of Set 10 | provideniya
# Processing Record 17 of Set 10 | talnakh
# Processing Record 18 of Set 10 | inirida
# Processing Record 19 of Set 10 | isla vista
# Processing Record 20 of Set 10 | lakatoro
# Processing Record 21 of Set 10 | vanimo
# Processing Record 22 of Set 10 | kondopoga
# Processing Record 23 of Set 10 | floresta
# Processing Record 24 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 10 | nouadhibou
# Processing Record 26 of Set 10 | korla
# Processing Record 27 of Set 10 | arinos
# Processing Record 28 of Set 10 | labuhan
# Processing Record 29 of Set 10 | ekhabi
# Processing Record 30 of Set 10 | puerto del rosario
# Processing Record 31 of Set 10 | cap malheureux
# Processing Record 32 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 10 | kuusankoski
# Processing Record 34 of Set 10 | yakeshi
# Processing Record 35 of Set 10 | carutapera
# Processing Record 36 of Set 10 | salvador
# Processing Record 37 of Set 10 | kavieng
# Processing Record 38 of Set 10 | ithaca
# Processing Record 39 of Set 10 | ahipara
# Processing Record 40 of Set 10 | orlik
# Processing Record 41 of Set 10 | batagay-alyta
# Processing Record 42 of Set 10 | kaeo
# Processing Record 43 of Set 10 | lagoa
# Processing Record 44 of Set 10 | ettaiyapuram
# Processing Record 45 of Set 10 | mpanda
# Processing Record 46 of Set 10 | simao
# Processing Record 47 of Set 10 | pulivendla
# Processing Record 48 of Set 10 | nerchinskiy zavod
# Processing Record 49 of Set 10 | upington
# Processing Record 50 of Set 10 | sucua
# Processing Record 1 of Set 11 | jamame
# Processing Record 2 of Set 11 | mattru
# Processing Record 3 of Set 11 | viedma
# Processing Record 4 of Set 11 | souris
# Processing Record 5 of Set 11 | corpus christi
# Processing Record 6 of Set 11 | kutulik
# Processing Record 7 of Set 11 | antalaha
# Processing Record 8 of Set 11 | evensk
# Processing Record 9 of Set 11 | krasnooktyabrskiy
# Processing Record 10 of Set 11 | sangar
# Processing Record 11 of Set 11 | corn island
# Processing Record 12 of Set 11 | liwale
# Processing Record 13 of Set 11 | kutum
# Processing Record 14 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 11 | maragogi
# Processing Record 16 of Set 11 | fez
# Processing Record 17 of Set 11 | manokwari
# Processing Record 18 of Set 11 | xinyang
# Processing Record 19 of Set 11 | henties bay
# Processing Record 20 of Set 11 | taltal
# Processing Record 21 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 22 of Set 11 | kiboga
# Processing Record 23 of Set 11 | kokopo
# Processing Record 24 of Set 11 | ornskoldsvik
# Processing Record 25 of Set 11 | zarand
# Processing Record 26 of Set 11 | mlonggo
# Processing Record 27 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 28 of Set 11 | udalguri
# Processing Record 29 of Set 11 | tanete
# Processing Record 30 of Set 11 | vila franca do campo
# Processing Record 31 of Set 11 | petushki
# Processing Record 32 of Set 11 | lata
# Processing Record 33 of Set 11 | kabo
# Processing Record 34 of Set 11 | tura
# Processing Record 35 of Set 11 | kruisfontein
# Processing Record 36 of Set 11 | laguna
# Processing Record 37 of Set 11 | betanzos
# Processing Record 38 of Set 11 | kitimat
# Processing Record 39 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 11 | adre
# Processing Record 42 of Set 11 | husavik
# Processing Record 43 of Set 11 | elko
# Processing Record 44 of Set 11 | talaya
# Processing Record 45 of Set 11 | killybegs
# Processing Record 46 of Set 11 | kralendijk
# Processing Record 47 of Set 11 | lima
# Processing Record 48 of Set 11 | alto araguaia
# Processing Record 49 of Set 11 | cacu
# Processing Record 50 of Set 11 | kathmandu
# Processing Record 1 of Set 12 | kirkwall
# Processing Record 2 of Set 12 | mogadishu
# Processing Record 3 of Set 12 | morondava
# Processing Record 4 of Set 12 | buckeye
# Processing Record 5 of Set 12 | phan thiet
# Processing Record 6 of Set 12 | kyra
# Processing Record 7 of Set 12 | bitung
# Processing Record 8 of Set 12 | sampit
# Processing Record 9 of Set 12 | povenets
# Processing Record 10 of Set 12 | oranjemund
# Processing Record 11 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 12 | vikhorevka
# Processing Record 13 of Set 12 | port shepstone
# Processing Record 14 of Set 12 | bowen
# Processing Record 15 of Set 12 | ishigaki
# Processing Record 16 of Set 12 | adrar
# Processing Record 17 of Set 12 | grindavik
# Processing Record 18 of Set 12 | yenagoa
# Processing Record 19 of Set 12 | torrington
# Processing Record 20 of Set 12 | dudinka
# Processing Record 21 of Set 12 | avera
# Processing Record 22 of Set 12 | bandarbeyla
# Processing Record 23 of Set 12 | maldonado
# Processing Record 24 of Set 12 | uralskiy
# City not found. Skipping...
# Processing Record 25 of Set 12 | touros
# Processing Record 26 of Set 12 | san juan
# Processing Record 27 of Set 12 | georgiyevskoye
# Processing Record 28 of Set 12 | kyshtovka
# Processing Record 29 of Set 12 | okha
# Processing Record 30 of Set 12 | skibbereen
# Processing Record 31 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 12 | kaduqli
# Processing Record 33 of Set 12 | namibe
# Processing Record 34 of Set 12 | santa maria del oro
# Processing Record 35 of Set 12 | santa vitoria
# Processing Record 36 of Set 12 | norsup
# Processing Record 37 of Set 12 | tondano
# Processing Record 38 of Set 12 | lixourion
# Processing Record 39 of Set 12 | rocha
# Processing Record 40 of Set 12 | oleksandrivka
# Processing Record 41 of Set 12 | yar-sale
# Processing Record 42 of Set 12 | sergiyevsk
# Processing Record 43 of Set 12 | hermagor
# Processing Record 44 of Set 12 | meilu
# City not found. Skipping...
# Processing Record 45 of Set 12 | antsohihy
# Processing Record 46 of Set 12 | batsfjord
# Processing Record 47 of Set 12 | bac lieu
# Processing Record 48 of Set 12 | pangai
# Processing Record 49 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 50 of Set 12 | carsamba
# Processing Record 1 of Set 13 | teguise
# Processing Record 2 of Set 13 | fare
# Processing Record 3 of Set 13 | zyryanka
# Processing Record 4 of Set 13 | pasinler
# Processing Record 5 of Set 13 | luanda
# Processing Record 6 of Set 13 | acajutla
# Processing Record 7 of Set 13 | murray bridge
# Processing Record 8 of Set 13 | waipawa
# Processing Record 9 of Set 13 | gwadar
# Processing Record 10 of Set 13 | bamiantong
# Processing Record 11 of Set 13 | aleksandrov gay
# Processing Record 12 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 13 | codrington
# Processing Record 14 of Set 13 | hambantota
# Processing Record 15 of Set 13 | prince rupert
# Processing Record 16 of Set 13 | pisco
# Processing Record 17 of Set 13 | the valley
# Processing Record 18 of Set 13 | salalah
# Processing Record 19 of Set 13 | ballina
# Processing Record 20 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 13 | gualaceo
# Processing Record 22 of Set 13 | mayo
# Processing Record 23 of Set 13 | karlskoga
# Processing Record 24 of Set 13 | panama city
# Processing Record 25 of Set 13 | beyneu
# Processing Record 26 of Set 13 | safranbolu
# Processing Record 27 of Set 13 | bari
# Processing Record 28 of Set 13 | nishihara
# Processing Record 29 of Set 13 | dauphin
# Processing Record 30 of Set 13 | xuddur
# Processing Record 31 of Set 13 | altyn-topkan
# Processing Record 32 of Set 13 | forrest city
# Processing Record 33 of Set 13 | santarem
# Processing Record 34 of Set 13 | yatou
# Processing Record 35 of Set 13 | las cruces
# Processing Record 36 of Set 13 | sheregesh
# Processing Record 37 of Set 13 | sakaiminato
# Processing Record 38 of Set 13 | thinadhoo
# Processing Record 39 of Set 13 | liuzhou
# Processing Record 40 of Set 13 | fortuna
# Processing Record 41 of Set 13 | civita castellana
# Processing Record 42 of Set 13 | kalisz
# Processing Record 43 of Set 13 | barra do garcas
# Processing Record 44 of Set 13 | zhigansk
# Processing Record 45 of Set 13 | lasa
# Processing Record 46 of Set 13 | aberfeldy
# Processing Record 47 of Set 13 | itarema
# Processing Record 48 of Set 13 | junction city
# Processing Record 49 of Set 13 | ambilobe
# Processing Record 50 of Set 13 | karratha
# Processing Record 1 of Set 14 | ontario
# Processing Record 2 of Set 14 | varzea da palma
# Processing Record 3 of Set 14 | hohhot
# Processing Record 4 of Set 14 | tongren
# Processing Record 5 of Set 14 | palu
# Processing Record 6 of Set 14 | puerto madero
# Processing Record 7 of Set 14 | khambhat
# Processing Record 8 of Set 14 | chumikan
# Processing Record 9 of Set 14 | zaykovo
# Processing Record 10 of Set 14 | sisimiut
# Processing Record 11 of Set 14 | wahiawa
# Processing Record 12 of Set 14 | mundo nuevo
# Processing Record 13 of Set 14 | beira
# Processing Record 14 of Set 14 | urumqi
# Processing Record 15 of Set 14 | villa carlos paz
# Processing Record 16 of Set 14 | yulara
# Processing Record 17 of Set 14 | iznik
# Processing Record 18 of Set 14 | preston
# Processing Record 19 of Set 14 | namatanai
# Processing Record 20 of Set 14 | vigrestad
# Processing Record 21 of Set 14 | ardakan
# Processing Record 22 of Set 14 | kirkenes
# Processing Record 23 of Set 14 | coari
# Processing Record 24 of Set 14 | chulym
# Processing Record 25 of Set 14 | ratnagiri
# Processing Record 26 of Set 14 | vari
# Processing Record 27 of Set 14 | shingu
# Processing Record 28 of Set 14 | khani
# Processing Record 29 of Set 14 | talcahuano
# Processing Record 30 of Set 14 | san joaquin
# Processing Record 31 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 32 of Set 14 | asfi
# Processing Record 33 of Set 14 | valparaiso
# Processing Record 34 of Set 14 | nalut
# Processing Record 35 of Set 14 | coron
# Processing Record 36 of Set 14 | buraydah
# Processing Record 37 of Set 14 | wichian buri
# Processing Record 38 of Set 14 | havre
# Processing Record 39 of Set 14 | leh
# Processing Record 40 of Set 14 | abeche
# Processing Record 41 of Set 14 | agadez
# Processing Record 42 of Set 14 | hwange
# Processing Record 43 of Set 14 | matagami
# Processing Record 44 of Set 14 | winnemucca
# Processing Record 45 of Set 14 | alikalia
# Processing Record 46 of Set 14 | sibolga
# Processing Record 47 of Set 14 | luebo
# Processing Record 48 of Set 14 | arman
# Processing Record 49 of Set 14 | tocopilla
# Processing Record 50 of Set 14 | crystal beach
# Processing Record 1 of Set 15 | bandar-e lengeh
# Processing Record 2 of Set 15 | atasu
# Processing Record 3 of Set 15 | matelandia
# Processing Record 4 of Set 15 | tokur
# Processing Record 5 of Set 15 | erzin
# Processing Record 6 of Set 15 | kysyl-syr
# Processing Record 7 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 8 of Set 15 | alihe
# Processing Record 9 of Set 15 | keti bandar
# Processing Record 10 of Set 15 | gorom-gorom
# Processing Record 11 of Set 15 | galle
# Processing Record 12 of Set 15 | tripoli
# Processing Record 13 of Set 15 | mezen
# Processing Record 14 of Set 15 | kristianstad
# Processing Record 15 of Set 15 | kaoma
# Processing Record 16 of Set 15 | san cristobal
# Processing Record 17 of Set 15 | berekum
# Processing Record 18 of Set 15 | anloga
# Processing Record 19 of Set 15 | aklavik
# Processing Record 20 of Set 15 | metkovic
# Processing Record 21 of Set 15 | taksimo
# Processing Record 22 of Set 15 | jiuquan
# Processing Record 23 of Set 15 | mantua
# Processing Record 24 of Set 15 | jasper
# Processing Record 25 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 26 of Set 15 | montelimar
# Processing Record 27 of Set 15 | jardim
# Processing Record 28 of Set 15 | tabas
# Processing Record 29 of Set 15 | sinnamary
# Processing Record 30 of Set 15 | matara
# Processing Record 31 of Set 15 | deerfield beach
# Processing Record 32 of Set 15 | la reforma
# Processing Record 33 of Set 15 | isla mujeres
# Processing Record 34 of Set 15 | mancora
# Processing Record 35 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 36 of Set 15 | magadi
# Processing Record 37 of Set 15 | chipinge
# Processing Record 38 of Set 15 | marsa matruh
# Processing Record 39 of Set 15 | cayenne
# Processing Record 40 of Set 15 | pakdasht
# Processing Record 41 of Set 15 | mokhotlong
# Processing Record 42 of Set 15 | najran
# Processing Record 43 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 44 of Set 15 | zeya
# Processing Record 45 of Set 15 | yelizovo
# Processing Record 46 of Set 15 | chiang klang
# Processing Record 47 of Set 15 | port-gentil
# Processing Record 48 of Set 15 | abu kamal
# Processing Record 49 of Set 15 | magadan
# Processing Record 50 of Set 15 | mizdah
# Processing Record 1 of Set 16 | shenzhen
# Processing Record 2 of Set 16 | high level
# Processing Record 3 of Set 16 | george town
# Processing Record 4 of Set 16 | lovington
# Processing Record 5 of Set 16 | ulladulla
# Processing Record 6 of Set 16 | kuminskiy
# Processing Record 7 of Set 16 | portland
# Processing Record 8 of Set 16 | tessalit
# Processing Record 9 of Set 16 | dunmore town
# Processing Record 10 of Set 16 | tarakan
# Processing Record 11 of Set 16 | quirinopolis
# Processing Record 12 of Set 16 | port augusta
# Processing Record 13 of Set 16 | sumbe
# Processing Record 14 of Set 16 | acarau
# Processing Record 15 of Set 16 | ituni
# City not found. Skipping...
# Processing Record 16 of Set 16 | zhongshu
# Processing Record 17 of Set 16 | eskasem
# City not found. Skipping...
# Processing Record 18 of Set 16 | tiznit
# Processing Record 19 of Set 16 | derzhavinsk
# Processing Record 20 of Set 16 | council bluffs
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 711

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat      Long  Max Temp  Humidity  Cloudiness  \
# 0      Yellowknife  62.4560 -114.3525     52.32        87          75
# 1  Bambous Virieux -20.3428   57.7575     73.22        60          75
# 2        Hithadhoo  -0.6000   73.0833     81.72        70          72
# 3          Ushuaia -54.8000  -68.3000     37.06        65          20
# 4        Cape Town -33.9258   18.4232     59.38        82           0
# 5            Kapaa  22.0752 -159.3190     84.18        75           0
# 6           Mikuni  36.2171  136.1519     75.11        64           4
# 7          Rikitea -23.1203 -134.9692     73.69        73           2
# 8      East London -33.0153   27.9116     63.54        88          20
# 9            Praya  14.9215  -23.5087     77.54        78          75
#
#    Wind Speed Country Current Description
# 0        9.22      CA       broken clouds
# 1       10.36      MU       broken clouds
# 2       15.88      MV       broken clouds
# 3       12.66      AR          few clouds
# 4        4.61      ZA           clear sky
# 5       11.50      US           clear sky
# 6        4.74      JP           clear sky
# 7       13.78      PF           clear sky
# 8        3.44      ZA          few clouds
# 9        9.22      CV       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Long', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_col_order = ["City", "Country", "Lat", "Long", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_col_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat      Long  Max Temp  Humidity  Cloudiness  \
# 0      Yellowknife      CA  62.4560 -114.3525     52.32        87          75
# 1  Bambous Virieux      MU -20.3428   57.7575     73.22        60          75
# 2        Hithadhoo      MV  -0.6000   73.0833     81.72        70          72
# 3          Ushuaia      AR -54.8000  -68.3000     37.06        65          20
# 4        Cape Town      ZA -33.9258   18.4232     59.38        82           0
# 5            Kapaa      US  22.0752 -159.3190     84.18        75           0
# 6           Mikuni      JP  36.2171  136.1519     75.11        64           4
# 7          Rikitea      PF -23.1203 -134.9692     73.69        73           2
# 8      East London      ZA -33.0153   27.9116     63.54        88          20
# 9            Praya      CV  14.9215  -23.5087     77.54        78          75
#
#    Wind Speed Current Description
# 0        9.22       broken clouds
# 1       10.36       broken clouds
# 2       15.88       broken clouds
# 3       12.66          few clouds
# 4        4.61           clear sky
# 5       11.50           clear sky
# 6        4.74           clear sky
# 7       13.78           clear sky
# 8        3.44          few clouds
# 9        9.22       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Long                   float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label = "City_ID")
